# %%
from scipy import stats

np.random.seed(1428)  # fix seed to get the same result

# %%
import numpy as np

# %%
x = np.linspace(-10, 10, 10000)
x1 = -1.96
x2 = 1.96
y1 = stats.norm.pdf(x1)
y2 = stats.norm.pdf(x2)
y = stats.norm.pdf(x)

plt.figure(figsize(16, 4))

plot(x, y, 'r' , lw=1)
scatter(x1, y1, marker='x', c='b', alpha=0.9)
scatter(x2, y2, marker='x', c='b', alpha=0.9)

# %%
x = np.linspace(-10, 10, 1000)
 
y = stats.norm.rvs(loc=0, scale=1, size=1000)

plt.figure(figsize(16, 4))

plot(x, y, 'r' , lw=1)
#scatter(x1, y1, marker='x', c='b', alpha=0.9)
#scatter(x2, y2, marker='x', c='b', alpha=0.9)

# %%
sum( y > 2 ) + sum(y < -2)
# Out:
# 455

# %%
stats.norm.rvs(-1.96)
# Out:
# -0.9429542807963982

# %%
df = pd.read_csv('./hypothethis/dedao-dau.csv')

# %%
df.head()
# Out:
#         udt  active_uv  active_didUV  delta delta2
# 0  20190101    1317387       1266555  3.86%  4.01%
# 1  20190102    1217155       1200815  1.34%  1.36%
# 2  20190103    1126486       1117427  0.80%  0.81%
# 3  20190104    1034932       1030099  0.47%  0.47%
# 4  20190105     897543        894293  0.36%  0.36%

# %%
from scipy import stats

stats.ttest_ind( df['active_uv'], df['active_didUV'], equal_var = False)
# Out:
# Ttest_indResult(statistic=0.15256127382161594, pvalue=0.8788109169244807)

# %%
rvs = stats.norm.rvs(loc=5, scale=10, size=(50,2))

# Test if mean of random sample is equal to true mean, and different mean. We reject the null hypothesis in the second case and don’t reject it in the first case.

stats.ttest_1samp(rvs,5.0)
# Out:
# Ttest_1sampResult(statistic=array([-0.68014479, -0.04323899]), pvalue=array([0.49961383, 0.96568674]))

# %%
from math import sqrt

sqrt(0.25)

8 /14
# Out:
# 0.5714285714285714

# %%
>>> 


>>>
>>> 
(array([-0.68014479, -0.04323899]), array([ 0.49961383,  0.96568674]))
>>> stats.ttest_1samp(rvs,0.0)
(array([ 2.77025808,  4.11038784]), array([ 0.00789095,  0.00014999]))
Examples using axis and non-scalar dimension for population mean.

>>>
>>> stats.ttest_1samp(rvs,[5.0,0.0])
(array([-0.68014479,  4.11038784]), array([  4.99613833e-01,   1.49986458e-04]))
>>> stats.ttest_1samp(rvs.T,[5.0,0.0],axis=1)
(array([-0.68014479,  4.11038784]), array([  4.99613833e-01,   1.49986458e-04]))
>>> stats.ttest_1samp(rvs,[[5.0],[0.0]])
(array([[-0.68014479, -0.04323899],
       [ 2.77025808,  4.11038784]]), array([[  4.99613833e-01,   9.65686743e-01],
       [  7.89094663e-03,   1.49986458e-04]]))
# Out:
#   File "<ipython-input-2-39fd7eb5531c>", line 2
#     Test if mean of random sample is equal to true mean, and different mean. We reject the null hypothesis in the second case and don’t reject it in the first case.
#                   ^
# SyntaxError: invalid syntax
